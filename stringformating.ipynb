# %%
nm=input("Enter the name:")
age= int(input('enter the age:'))
# print(f"my name is {nm} and  is {age}")

msg= "hii {nm} your age is {age}"
mydata= msg.format(nm=nm,age=age)
print(mydata)
# Out:
# hii suneel  your age is 23

# %%
nm=input("Enter the name:")
age= int(input('enter the age:'))

msg= "hii {1} your age is {0}"
mydata= msg.format(nm,age)
print(mydata)
# Out:
# hii 34 your age is suneel
