# %% [markdown]
# Decorator:-
#
# Decorator एक ऐसा function होता है जो किसी दूसरे function को बिना बदले उसमें extra काम जोड़ देता है।
#
# 📌 आसान शब्दों में:
#
# Function को सजाना (decorate करना)

# %%
def my_decorator(func):
    def wrapper():
        print("Function से पहले")
        func()
        print("Function के बाद")
    return wrapper

@my_decorator
def hello():
    print("Hello World")

# %%
def decor(func):
    def inner(name):
        if name== "small princeness":
            print('welcome princeness ')
        else:
            func(name)
    return inner
# @decor
# def myfunc(name):
#     print("suneel")

# myfunc('krish')
# myfunc('small princeness')

def myfunc(name):
    print("suneel")

var1=decor(myfunc)
var1('small princeness')
# Out:
# welcome princeness

# %% [markdown]
# Generator
#
# Generator एक special function होता है
# जो रुक-रुक कर value देता है (one by one)
#
# 👉 Generator:
#
# थोड़ा चलता है
#
# रुकता है
#
# फिर आगे चलता है

# %%
def mygen():
    yield "suneel"
    yield "2"
    yield "3"
var= mygen()
print(next(var))
print(next(var))
print(next(var))
# Out:
# suneel
# 2
# 3
